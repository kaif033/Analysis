# %% [markdown]
# <a href="https://colab.research.google.com/github/kaif033/Analysis/blob/main/advanceregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
filepath1=('/content/train.csv')
filepath2=('/content/test.csv')
df1=pd.read_csv(filepath1)
df2=pd.read_csv(filepath2)

# %%
pd.pandas.set_option('display.max_columns',None)

# %%
df2.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df1.shape
# Out:
# (1460, 81)

# %%
feature_with_na=[feature for feature in df1.columns  if df1[feature].isnull().sum()>1 ]
for feature in feature_with_na:
  print(feature , np.round(df1[feature].isnull().mean(),4))
# Out:
# LotFrontage 0.1774
# Alley 0.9377
# MasVnrType 0.0055
# MasVnrArea 0.0055
# BsmtQual 0.0253
# BsmtCond 0.0253
# BsmtExposure 0.026
# BsmtFinType1 0.0253
# BsmtFinType2 0.026
# FireplaceQu 0.4726
# GarageType 0.0555
# GarageYrBlt 0.0555
# GarageFinish 0.0555
# GarageQual 0.0555
# GarageCond 0.0555
# PoolQC 0.9952
# Fence 0.8075
# MiscFeature 0.963

# %%
# since there are many missing values we need to plot them and figure out
# the relation between them
for feature in feature_with_na:
    data = df1.copy()

    # let's make a variable that indicates 1 if the observation was missing or zero otherwise
    data[feature] = np.where(data[feature].isnull(), 1, 0)

    # let's calculate the mean SalePrice where the information is missing or present
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [markdown]
# here the missing values and dependent variables is clearly visible .
# so we need to replace these nam with somwthing meaningful which we will do in feature engineering

# %%
numerical_features=[feature for feature in df1.columns if df1[feature].dtypes !="O"]
print('Numberof numerical variables',len(numerical_features))
df1[numerical_features].head()
# Out:
# Numberof numerical variables 38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
year_feature=[feature for feature in numerical_features if 'Year'in feature
              or 'Yr' in feature]
for feature in year_feature:
  print(feature)
# Out:
# YearBuilt
# YearRemodAdd
# GarageYrBlt
# YrSold

# %%
for feature in year_feature:
  print(feature,df1[feature].unique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
# lets check the relation between sales price and year sold
df1.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('yearSold')
plt.ylabel('median house Price')
plt.title('house price vs YearSold')
# Out:
# Text(0.5, 1.0, 'house price vs YearSold')

# %%
for feature in year_feature:
  if feature!='YrSold':
    data=df1.copy()
    data[feature]=data['YrSold']-data[feature]

    plt.scatter(data[feature],data['SalePrice'])
    plt.xlabel(feature)
    plt.ylabel('Sales Price')
    plt.show()

# %%
discrete_feature=[feature for feature in numerical_features if len(df1[feature].unique())<25
                            and feature not in year_feature+['id']]
print(len(discrete_feature))
discrete_feature
# Out:
# 17
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
df1[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0          60            7            5             0             1
# 1          20            6            8             0             0
# 2          60            7            5             0             1
# 3          70            7            5             0             1
# 4          60            8            5             0             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         1             3             1             8
# 1             1         2         0             3             1             6
# 2             0         2         1             3             1             6
# 3             0         1         0             3             1             7
# 4             0         2         1             4             1             9
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
for feature in discrete_feature:
  data=df1.copy()
  data.groupby(feature)['SalePrice'].median().plot.bar()
  plt.xlabel(feature)
  plt.ylabel("SalePrice")
  plt.title(feature)
  plt.show()

# %%
cont_feature=[feature for feature in numerical_features if feature not in discrete_feature
                            and feature not in year_feature+['id']]
print(len(cont_feature))
cont_feature
# Out:
# 17
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for feature in cont_feature:
  data=df1.copy()
  if feature!='Id':
    data[feature].hist(bins=50)
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.title(feature)
    plt.show()

# %%
#we will be using logarthmic transformation

# %%
for feature in cont_feature:
  data=df1.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature]=np.log(data[feature])
    data['SalePrice']=np.log(data['SalePrice'])
    fig=px.scatter(data,data[feature],data['SalePrice'])
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for feature in cont_feature:
  data=df1.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature]=np.log(data[feature])
    data[feature].hist(bins=50)
    plt.title(feature)
    plt.show()

# %%
# handling outlers
for feature in cont_feature:
  data=df1.copy()
  if 0 in data[feature].unique():
    pass
  else:
    data[feature]=np.log(data[feature])
    fig=px.box(data,y=data[feature])
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# categorical variables
categorical_feature=[feature for feature in df1.columns if df1[feature].dtypes=="O"]
categorical_feature
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
df1[categorical_feature].head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 3      Crawfor       Norm       Norm     1Fam     2Story     Gable  CompShg
# 4      NoRidge       Norm       Norm     1Fam     2Story     Gable  CompShg
#
# ...

# %%
for feature in categorical_feature:
  print("feature  {} and unique categories are : {}".format(feature,df1[feature].nunique()))
  print()
# Out:
# feature  MSZoning and unique categories are : 5
#
# feature  Street and unique categories are : 2
#
# feature  Alley and unique categories are : 2
#
# feature  LotShape and unique categories are : 4
#
# feature  LandContour and unique categories are : 4
#
# feature  Utilities and unique categories are : 2
#
# feature  LotConfig and unique categories are : 5
#
# feature  LandSlope and unique categories are : 3
#
# feature  Neighborhood and unique categories are : 25
#
# feature  Condition1 and unique categories are : 9
#
# feature  Condition2 and unique categories are : 8
#
# feature  BldgType and unique categories are : 5
#
# feature  HouseStyle and unique categories are : 8
#
# feature  RoofStyle and unique categories are : 6
#
# feature  RoofMatl and unique categories are : 8
#
# feature  Exterior1st and unique categories are : 15
#
# feature  Exterior2nd and unique categories are : 16
#
# feature  MasVnrType and unique categories are : 4
#
# ...

# %%
# finding the realtionship between categorical variables and sales prize
color = ['lightblue', 'blue', 'purple', 'red', 'black']
for feature in categorical_feature:
  data=df1.copy()
  data.groupby(feature)['SalePrice'].median().plot.bar(color=color)
  plt.xlabel(feature)
  plt.ylabel('saleprice')
  plt.show()
  print( )

# %%
# feature Engineering
#feature with nan in categorical
feature_with_nan_cat=[feature for feature in df1.columns
                      if df1[feature].isnull().sum()>1  and df1[feature].dtypes=="O"]
for feature  in feature_with_nan_cat:
  print(feature , np.round(df1[feature].isnull().mean(),4))
# Out:
# Alley 0.9377
# MasVnrType 0.0055
# BsmtQual 0.0253
# BsmtCond 0.0253
# BsmtExposure 0.026
# BsmtFinType1 0.0253
# BsmtFinType2 0.026
# FireplaceQu 0.4726
# GarageType 0.0555
# GarageFinish 0.0555
# GarageQual 0.0555
# GarageCond 0.0555
# PoolQC 0.9952
# Fence 0.8075
# MiscFeature 0.963

# %%
def replace_cat_feature(df1,feature_with_nan_cat):
  data=df1.copy()
  data[feature_with_nan_cat]=data[feature_with_nan_cat].fillna('missing')
  return data
df1=replace_cat_feature(df1,feature_with_nan_cat)
df1[feature_with_nan_cat].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
df1[feature_with_nan_cat].head()
# Out:
#      Alley MasVnrType BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0  missing    BrkFace       Gd       TA           No          GLQ
# 1  missing       None       Gd       TA           Gd          ALQ
# 2  missing    BrkFace       Gd       TA           Mn          GLQ
# 3  missing       None       TA       Gd           No          ALQ
# 4  missing    BrkFace       Gd       TA           Av          GLQ
#
#   BsmtFinType2 FireplaceQu GarageType GarageFinish GarageQual GarageCond  \
# 0          Unf     missing     Attchd          RFn         TA         TA
# 1          Unf          TA     Attchd          RFn         TA         TA
# 2          Unf          TA     Attchd          RFn         TA         TA
# 3          Unf          Gd     Detchd          Unf         TA         TA
# 4          Unf          TA     Attchd          RFn         TA         TA
#
#     PoolQC    Fence MiscFeature
# 0  missing  missing     missing
# 1  missing  missing     missing
# ...

# %%
# numerical nan
numerical_with_nan=[feature for feature in df1.columns if df1[feature].dtypes !="O" and df1[feature].isnull().sum()>1]
print('Numberof numerical variables',len(numerical_with_nan))
for feature  in numerical_with_nan:
  print(feature , np.round(df1[feature].isnull().mean(),4))
# Out:
# Numberof numerical variables 3
# LotFrontage 0.1774
# MasVnrArea 0.0055
# GarageYrBlt 0.0555

# %%
for feature in numerical_with_nan:
  df1[feature+"nan"]=np.where(df1[feature].isnull(),1,0)
  df1[feature]=df1[feature].fillna(df1[feature].median())
df1[numerical_with_nan].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
df1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       RL         65.0     8450   Pave  missing
# 1        2          20       RL         80.0     9600   Pave  missing
# 2        3          60       RL         68.0    11250   Pave  missing
# 3        4          70       RL         60.0     9550   Pave  missing
# 4        5          60       RL         84.0    14260   Pave  missing
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  missing
# 1456  1457          20       RL         85.0    13175   Pave  missing
# 1457  1458          70       RL         66.0     9042   Pave  missing
# 1458  1459          20       RL         68.0     9717   Pave  missing
# 1459  1460          20       RL         75.0     9937   Pave  missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
# dealing with temporal varibales
# datetime variables
year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_feature:
  if feature!='YrSold':
    df1[feature]=df1['YrSold']- df1[feature]

# %%
df1.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave  missing      Reg
# 1   2          20       RL         80.0     9600   Pave  missing      Reg
# 2   3          60       RL         68.0    11250   Pave  missing      IR1
# 3   4          70       RL         60.0     9550   Pave  missing      IR1
# 4   5          60       RL         84.0    14260   Pave  missing      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df1[year_feature]
# Out:
#       YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0             5             5          5.0    2008
# 1            31            31         31.0    2007
# 2             7             6          7.0    2008
# 3            91            36          8.0    2006
# 4             8             8          8.0    2008
# ...         ...           ...          ...     ...
# 1455          8             7          8.0    2007
# 1456         32            22         32.0    2010
# 1457         69             4         69.0    2010
# 1458         60            14         60.0    2010
# 1459         43            43         43.0    2008
#
# [1460 rows x 4 columns]

# %%
df1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       RL         65.0     8450   Pave  missing
# 1        2          20       RL         80.0     9600   Pave  missing
# 2        3          60       RL         68.0    11250   Pave  missing
# 3        4          70       RL         60.0     9550   Pave  missing
# 4        5          60       RL         84.0    14260   Pave  missing
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  missing
# 1456  1457          20       RL         85.0    13175   Pave  missing
# 1457  1458          70       RL         66.0     9042   Pave  missing
# 1458  1459          20       RL         68.0     9717   Pave  missing
# 1459  1460          20       RL         75.0     9937   Pave  missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
import numpy as np
num_features=['LotFrontage', 'MasVnrArea', 'GarageYrBlt','SalePrice']
for feature in num_features:
  df1[feature]=np.log(df1[feature])
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning:
#
# divide by zero encountered in log

# %%
df1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       RL     4.174387     8450   Pave  missing
# 1        2          20       RL     4.382027     9600   Pave  missing
# 2        3          60       RL     4.219508    11250   Pave  missing
# 3        4          70       RL     4.094345     9550   Pave  missing
# 4        5          60       RL     4.430817    14260   Pave  missing
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL     4.127134     7917   Pave  missing
# 1456  1457          20       RL     4.442651    13175   Pave  missing
# 1457  1458          70       RL     4.189655     9042   Pave  missing
# 1458  1459          20       RL     4.219508     9717   Pave  missing
# 1459  1460          20       RL     4.317488     9937   Pave  missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
#handling rare categorical feature
categorical=[feature for feature in df1.columns if df1[feature].dtype=="O"]

# %%
categorical
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical:
  temp=df1.groupby(feature)['SalePrice'].count()/len(df1)
  temp_df=temp[temp>0.01].index
  df1[feature]=np.where(df1[feature].isin(temp_df),df1[feature],"Rare_var")

# %%
df1.head(100)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape  \
# 0     1          60       RL     4.174387     8450   Pave  missing      Reg
# 1     2          20       RL     4.382027     9600   Pave  missing      Reg
# 2     3          60       RL     4.219508    11250   Pave  missing      IR1
# 3     4          70       RL     4.094345     9550   Pave  missing      IR1
# 4     5          60       RL     4.430817    14260   Pave  missing      IR1
# ..  ...         ...      ...          ...      ...    ...      ...      ...
# 95   96          60       RL     4.234107     9765   Pave  missing      IR2
# 96   97          20       RL     4.356709    10264   Pave  missing      IR1
# 97   98          20       RL     4.290459    10921   Pave  missing      Reg
# 98   99          30       RL     4.442651    10625   Pave  missing      Reg
# 99  100          20       RL     4.343805     9320   Pave  missing      IR1
#
# ...

# %%
for feature in categorical:
    labels_ordered=df1.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    df1[feature]=df1[feature].map(labels_ordered)

# %%
df1.head()
# Out:
#   Id MSSubClass MSZoning  LotFrontage LotArea Street Alley LotShape  \
# 0  1         60        3     4.174387    8450      1     2        0
# 1  2         20        3     4.382027    9600      1     2        0
# 2  3         60        3     4.219508   11250      1     2        1
# 3  4         70        3     4.094345    9550      1     2        1
# 4  5         60        3     4.430817   14260      1     2        1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0           1         1         0         0           14          2
# 1           1         1         2         0           11          1
# 2           1         1         0         0           14          2
# 3           1         1         1         0           16          2
# 4           1         1         2         0           22          2
#
#   Condition2 BldgType HouseStyle OverallQual OverallCond YearBuilt  \
# 0          1        3          5           7           5         5
# ...

# %%
df1["MasVnrArea"].dtypes
# Out:
# dtype('float64')

# %%
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/compilerop.py in ast_parse(self, source, filename, symbol)
#      99         Arguments are exactly the same as ast.parse (in the standard library),
#     100         and are passed to the built-in compile function."""
# --> 101         return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#     102
#     103     def reset_compiler_flags(self):
#
# SyntaxError: incomplete input (<ipython-input-71-512f684e0865>, line 2)

# %%
# feature scaling
feature_sc=[feature  for feature in df1.columns if feature not in ['Id','SalePrice']]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(df1[feature_sc])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-3205f3828c47> in <cell line: 5>()
#       3 from sklearn.preprocessing import MinMaxScaler
#       4 scaler=MinMaxScaler()
# ----> 5 scaler.fit(df1[feature_sc])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     425         # Reset internal state before fitting
#     426         self._reset()
# --> 427         return self.partial_fit(X, y)
#     428
#     429     def partial_fit(self, X, y=None):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     464
#     465         first_pass = not hasattr(self, "n_samples_seen_")
# --> 466         X = self._validate_data(
#     467             X,
#     468             reset=first_pass,
#
# ...

# %%
df1.head()
